# %%
# %load_ext autoreload
# %autoreload 2

# %%
import musicaljuggling.automata.musical_siteswap as ms
import networkx as nx

# %%
au_clair_de_la_lune = ["C", "C", "C", "D", "E", "", "D", "", "C", "E", "D", "D", "C"]
beau_danube = [
    "C", "E", "G",
    "G", "", "",
    "", "", "",
    "", "", "C",
    "C", "E", "G",
    "G", "", "",
    "", "", "",
    "", "", "D",
    "D", "F", "A'",
    "A'", "", "",
    "", "", "",
    "", "", "D",
    "D", "F", "A'",
    "A'", "", "",
    "", "", "",
    "", "", "C",
    "C", "E", "G",
    "C'", "", "",
    "", "", "",
    "", "", "C",
    "C", "E", "G",
    "C'", "", "",
    "", "", "",
    "", "", "D",
    "D", "F", "A'",
    "A'", "", "",
]
music = ["C", "D", "D", "D", "C"]

test = ms.MusicalAutomaton(beau_danube, 5, autobuild=False)
aut = test.automaton

# %%
test.build_initial_states()
'''for state in test.initial_states:
    print(state)'''
# Out:
# DE<| X | CXXXXX | t=0
# D<| E | CXXXXX | t=0
# D<| X | CEXXXX | t=0
# D<| X | CXEXXX | t=0
# D<| X | CXXEXX | t=0
# D<| X | CXXXEX | t=0
# D<| X | CXXXXE | t=0
# E<| D | CXXXXX | t=0
# X<| DE | CXXXXX | t=0
# X<| D | CEXXXX | t=0
# X<| D | CXEXXX | t=0
# X<| D | CXXEXX | t=0
# X<| D | CXXXEX | t=0
# X<| D | CXXXXE | t=0
# E<| X | CDXXXX | t=0
# E<| X | CXDXXX | t=0
# E<| X | CXXDXX | t=0
# E<| X | CXXXDX | t=0
# E<| X | CXXXXD | t=0
# X<| E | CDXXXX | t=0
# X<| E | CXDXXX | t=0
# X<| E | CXXDXX | t=0
# X<| E | CXXXDX | t=0
# X<| E | CXXXXD | t=0
# X<| X | CDEXXX | t=0
# X<| X | CDXEXX | t=0
# X<| X | CDXXEX | t=0
# X<| X | CDXXXE | t=0
# X<| X | CEDXXX | t=0
# X<| X | CXDEXX | t=0
# X<| X | CXDXEX | t=0
# X<| X | CXDXXE | t=0
# X<| X | CEXDXX | t=0
# X<| X | CXEDXX | t=0
# X<| X | CXXDEX | t=0
# X<| X | CXXDXE | t=0
# X<| X | CEXXDX | t=0
# X<| X | CXEXDX | t=0
# X<| X | CXXEDX | t=0
# X<| X | CXXXDE | t=0
# X<| X | CEXXXD | t=0
# X<| X | CXEXXD | t=0
# X<| X | CXXEXD | t=0
# X<| X | CXXXED | t=0

# %%
test.build_transitions()
print("Nodes :")
for node in aut.nodes:
    print(node)
print("\nEdges :")
for edge in aut.edges:
    print(edge[0])
    print(edge[1])
    print("---")
# Out:
# Nodes :
# X<| X | CXEXDX | t=0
# X<| X | CEXXXD | t=0
# X<| X | CXEXXD | t=0
# X<| X | CXXXDE | t=0
# X<| E | CXDXXX | t=0
# X<| X | CDXXXE | t=0
# X<| E | CXXDXX | t=0
# E<| X | CXXXDX | t=0
# D<| E | CXXXXX | t=0
# X<| D | CXXEXX | t=0
# D<| X | CEXXXX | t=0
# X<| X | CDXEXX | t=0
# X<| X | CXXDEX | t=0
# X<| X | CXXEXD | t=0
# D<| X | CXEXXX | t=0
# X<| X | CXXXED | t=0
# X<| E | CDXXXX | t=0
# X<| X | CXXDXE | t=0
# E<| X | CXXXXD | t=0
# E<| X | CDXXXX | t=0
# X<| DE | CXXXXX | t=0
# X<| D | CXXXEX | t=0
# X<| D | CXXXXE | t=0
# X<| X | CDEXXX | t=0
# D<| X | CXXXEX | t=0
# D<| X | CXXXXE | t=0
# E<| X | CXXDXX | t=0
# X<| X | CXDXXE | t=0
# X<| X | CEXXDX | t=0
# X<| X | CEDXXX | t=0
# X<| X | CEXDXX | t=0
# X<| E | CXXXXD | t=0
# E<| D | CXXXXX | t=0
# X<| X | CXXEDX | t=0
# X<| X | CDXXEX | t=0
# X<| X | CXDEXX | t=0
# X<| D | CEXXXX | t=0
# D<| X | CXXEXX | t=0
# X<| X | CXEDXX | t=0
# DE<| X | CXXXXX | t=0
# X<| D | CXEXXX | t=0
# X<| X | CXDXEX | t=0
# X<| E | CXXXDX | t=0
# E<| X | CXDXXX | t=0
# X |>X | CEXDXX | t=1
# X |>X | CEXXDX | t=1
# X |>X | CXXDEX | t=1
# X |>E | CDXXXX | t=1
# X |>E | CXDXXX | t=1
# E |>X | CXXDXX | t=1
# D |>E | CXXXXX | t=1
# X |>D | CXEXXX | t=1
# X |>X | CXDEXX | t=1
# X |>X | CXEXDX | t=1
# D |>X | CEXXXX | t=1
# X |>X | CXXEDX | t=1
# X |>X | CXDXEX | t=1
# E |>X | CXXXDX | t=1
# X |>DE | CXXXXX | t=1
# X |>D | CXXEXX | t=1
# X |>D | CXXXEX | t=1
# D |>X | CXXEXX | t=1
# D |>X | CXXXEX | t=1
# E |>X | CXDXXX | t=1
# X |>X | CDXXEX | t=1
# X |>E | CXXXDX | t=1
# E |>D | CXXXXX | t=1
# X |>X | CXEDXX | t=1
# X |>X | CDEXXX | t=1
# D |>X | CXEXXX | t=1
# X |>X | CEDXXX | t=1
# DE |>X | CXXXXX | t=1
# X |>D | CEXXXX | t=1
# X |>X | CDXEXX | t=1
# X |>E | CXXDXX | t=1
# E |>X | CDXXXX | t=1
# X<| X | CDXEXX | t=2
# X<| D | CEXXXX | t=2
# D<| X | CXEXXX | t=2
# X<| E | CXXDXX | t=2
# X<| E | CDXXXX | t=2
# E<| X | CDXXXX | t=2
# X<| X | CEXDXX | t=2
# D<| E | CXXXXX | t=2
# D<| X | CEXXXX | t=2
# X<| E | CXDXXX | t=2
# X<| X | CXDEXX | t=2
# X<| DE | CXXXXX | t=2
# E<| X | CXXDXX | t=2
# X<| D | CXEXXX | t=2
# X<| X | CEDXXX | t=2
# E<| X | CXDXXX | t=2
# X<| D | CXXEXX | t=2
# DE<| X | CXXXXX | t=2
# E<| D | CXXXXX | t=2
# X<| X | CXEDXX | t=2
# X<| X | CDEXXX | t=2
# D<| X | CXXEXX | t=2
# C |>X | DXEXXX | t=3
# EC |>X | DXXXXX | t=3
# C |>E | DXXXXX | t=3
# X |>X | DCEXXX | t=3
# X |>X | DXECXX | t=3
# X |>X | DXEXCX | t=3
# X |>X | DXEXXC | t=3
# C |>X | DEXXXX | t=3
# X |>E | DCXXXX | t=3
# X |>E | DXCXXX | t=3
# X |>E | DXXCXX | t=3
# X |>E | DXXXCX | t=3
# X |>E | DXXXXC | t=3
# C |>X | DXXEXX | t=3
# C |>X | DXXXEX | t=3
# C |>X | DXXXXE | t=3
# E |>X | DCXXXX | t=3
# E |>X | DXCXXX | t=3
# E |>X | DXXCXX | t=3
# E |>X | DXXXCX | t=3
# E |>X | DXXXXC | t=3
# X |>X | DECXXX | t=3
# X |>X | DEXCXX | t=3
# X |>X | DEXXCX | t=3
# X |>X | DEXXXC | t=3
# X<| D | ECXXXX | t=4
# X<| D | EXCXXX | t=4
# X<| X | EDCXXX | t=4
# X<| X | EXCDXX | t=4
# X<| X | EXCXDX | t=4
# X<| X | EXCXXD | t=4
# C<| D | EXXXXX | t=4
# C<| X | EDXXXX | t=4
# C<| X | EXDXXX | t=4
# C<| X | EXXDXX | t=4
# C<| X | EXXXDX | t=4
# C<| X | EXXXXD | t=4
# X<| D | EXXCXX | t=4
# X<| D | EXXXCX | t=4
# X<| X | EDXXCX | t=4
# X<| X | EXDXCX | t=4
# X<| X | EXXDCX | t=4
# X<| X | EXXXCD | t=4
# X<| X | EDXCXX | t=4
# X<| X | EXDCXX | t=4
# X<| X | EXXCDX | t=4
# X<| X | EXXCXD | t=4
# X<| X | ECDXXX | t=4
# X<| X | ECXDXX | t=4
# X<| X | ECXXDX | t=4
# X<| X | ECXXXD | t=4
# CE |>X | XXXDXX | t=5
# E |>X | XCXDXX | t=5
# E |>X | XXCDXX | t=5
# E |>X | XXXDCX | t=5
# E |>X | XXXDXC | t=5
# C |>X | XEXDXX | t=5
# C |>X | XXEDXX | t=5
# C |>X | XXXDEX | t=5
# C |>X | XXXDXE | t=5
# E |>X | XXCXDX | t=5
# X |>X | XECXDX | t=5
# X |>X | XXCEDX | t=5
# X |>X | XXCXDE | t=5
# E |>X | XCDXXX | t=5
# X |>X | XCDEXX | t=5
# X |>X | XCDXEX | t=5
# X |>X | XCDXXE | t=5
# E |>D | XXCXXX | t=5
# X |>D | XECXXX | t=5
# X |>D | XXCEXX | t=5
# X |>D | XXCXEX | t=5
# X |>D | XXCXXE | t=5
# CE |>X | XDXXXX | t=5
# E |>X | XDCXXX | t=5
# E |>X | XDXCXX | t=5
# E |>X | XDXXCX | t=5
# E |>X | XDXXXC | t=5
# C |>X | XDEXXX | t=5
# C |>X | XDXEXX | t=5
# C |>X | XDXXEX | t=5
# C |>X | XDXXXE | t=5
# E |>X | XXXCDX | t=5
# X |>X | XEXCDX | t=5
# X |>X | XXECDX | t=5
# X |>X | XXXCDE | t=5
# X |>X | XCEDXX | t=5
# X |>X | XCXDEX | t=5
# X |>X | XCXDXE | t=5
# E |>X | XCXXDX | t=5
# X |>X | XCEXDX | t=5
# X |>X | XCXEDX | t=5
# X |>X | XCXXDE | t=5
# CE |>X | XXXXDX | t=5
# E |>X | XXXXDC | t=5
# C |>X | XEXXDX | t=5
# C |>X | XXEXDX | t=5
# C |>X | XXXEDX | t=5
# C |>X | XXXXDE | t=5
# E |>D | XCXXXX | t=5
# X |>D | XCEXXX | t=5
# X |>D | XCXEXX | t=5
# X |>D | XCXXEX | t=5
# X |>D | XCXXXE | t=5
# E |>X | XXDCXX | t=5
# X |>X | XEDCXX | t=5
# X |>X | XXDCEX | t=5
# X |>X | XXDCXE | t=5
# E |>D | XXXCXX | t=5
# X |>D | XEXCXX | t=5
# X |>D | XXECXX | t=5
# X |>D | XXXCEX | t=5
# X |>D | XXXCXE | t=5
# X |>X | XECDXX | t=5
# X |>X | XXCDEX | t=5
# X |>X | XXCDXE | t=5
# X |>X | XDECXX | t=5
# X |>X | XDXCEX | t=5
# X |>X | XDXCXE | t=5
# CE |>X | XXDXXX | t=5
# E |>X | XXDXCX | t=5
# E |>X | XXDXXC | t=5
# C |>X | XEDXXX | t=5
# C |>X | XXDEXX | t=5
# C |>X | XXDXEX | t=5
# C |>X | XXDXXE | t=5
# X |>X | XDCEXX | t=5
# X |>X | XDCXEX | t=5
# X |>X | XDCXXE | t=5
# CE |>D | XXXXXX | t=5
# E |>D | XXXXCX | t=5
# E |>D | XXXXXC | t=5
# C |>D | XEXXXX | t=5
# C |>D | XXEXXX | t=5
# C |>D | XXXEXX | t=5
# C |>D | XXXXEX | t=5
# C |>D | XXXXXE | t=5
# X<| X | DCXXEX | t=6
# C<| X | DXEXXX | t=6
# C<| X | DXXEXX | t=6
# X<| X | DXCXEX | t=6
# E<| X | DXXXCX | t=6
# X<| X | DECXXX | t=6
# X<| X | DXCEXX | t=6
# X<| X | DCEXXX | t=6
# CE<| X | DXXXXX | t=6
# C<| X | DEXXXX | t=6
# E<| X | DXXCXX | t=6
# C<| X | DXXXEX | t=6
# E<| X | DXCXXX | t=6
# X<| X | DCXEXX | t=6
# E<| X | DCXXXX | t=6
# CD |>X | XEXXXX | t=7
# D |>X | XECXXX | t=7
# D |>X | XEXCXX | t=7
# D |>X | XEXXCX | t=7
# D |>X | XEXXXC | t=7
# C |>X | XEDXXX | t=7
# C |>X | XEXDXX | t=7
# C |>X | XEXXDX | t=7
# C |>X | XEXXXD | t=7
# D |>X | XCXEXX | t=7
# X |>X | XCDEXX | t=7
# X |>X | XCXEDX | t=7
# X |>X | XCXEXD | t=7
# CED |>X | XXXXXX | t=7
# ED |>X | XCXXXX | t=7
# ED |>X | XXCXXX | t=7
# ED |>X | XXXCXX | t=7
# ED |>X | XXXXCX | t=7
# ED |>X | XXXXXC | t=7
# CD |>X | XXEXXX | t=7
# CD |>X | XXXEXX | t=7
# CD |>X | XXXXEX | t=7
# CD |>X | XXXXXE | t=7
# CE |>X | XDXXXX | t=7
# CE |>X | XXDXXX | t=7
# CE |>X | XXXDXX | t=7
# CE |>X | XXXXDX | t=7
# CE |>X | XXXXXD | t=7
# D |>X | XXCEXX | t=7
# D |>X | XXCXEX | t=7
# D |>X | XXCXXE | t=7
# E |>X | XDCXXX | t=7
# E |>X | XXCDXX | t=7
# E |>X | XXCXDX | t=7
# E |>X | XXCXXD | t=7
# D |>X | XCEXXX | t=7
# D |>X | XCXXEX | t=7
# D |>X | XCXXXE | t=7
# E |>X | XCDXXX | t=7
# E |>X | XCXDXX | t=7
# E |>X | XCXXDX | t=7
# E |>X | XCXXXD | t=7
# D |>X | XXECXX | t=7
# D |>X | XXXCEX | t=7
# D |>X | XXXCXE | t=7
# E |>X | XDXCXX | t=7
# E |>X | XXDCXX | t=7
# E |>X | XXXCDX | t=7
# E |>X | XXXCXD | t=7
# D |>X | XXEXCX | t=7
# D |>X | XXEXXC | t=7
# C |>X | XDEXXX | t=7
# C |>X | XXEDXX | t=7
# C |>X | XXEXDX | t=7
# C |>X | XXEXXD | t=7
# D |>X | XXXECX | t=7
# D |>X | XXXEXC | t=7
# C |>X | XDXEXX | t=7
# C |>X | XXDEXX | t=7
# C |>X | XXXEDX | t=7
# C |>X | XXXEXD | t=7
# X |>X | XCEDXX | t=7
# X |>X | XCEXDX | t=7
# X |>X | XCEXXD | t=7
# X<| X | CXEXDX | t=8
# D<| X | CXEXXX | t=8
# X<| X | CEDXXX | t=8
# D<| X | CXXEXX | t=8
# E<| X | CDXXXX | t=8
# ED<| X | CXXXXX | t=8
# X<| X | CXEDXX | t=8
# D<| X | CEXXXX | t=8
# E<| X | CXXDXX | t=8
# X<| X | CEXDXX | t=8
# X<| X | CEXXDX | t=8
# E<| X | CXXXDX | t=8
# D<| X | CXXXEX | t=8
# E<| X | CXDXXX | t=8
# X<| X | CDEXXX | t=8
# C |>X | EDXXXX | t=9
# X |>X | EDCXXX | t=9
# X |>X | EDXCXX | t=9
# X |>X | EDXXCX | t=9
# X |>X | EDXXXC | t=9
# C |>X | EXDXXX | t=9
# C |>X | EXXDXX | t=9
# X |>X | ECXDXX | t=9
# X |>X | EXCDXX | t=9
# X |>X | EXXDCX | t=9
# X |>X | EXXDXC | t=9
# X |>X | ECDXXX | t=9
# X |>X | EXDCXX | t=9
# X |>X | EXDXCX | t=9
# X |>X | EXDXXC | t=9
# DC |>X | EXXXXX | t=9
# C |>X | EXXXDX | t=9
# C |>X | EXXXXD | t=9
# D |>X | ECXXXX | t=9
# D |>X | EXCXXX | t=9
# D |>X | EXXCXX | t=9
# D |>X | EXXXCX | t=9
# D |>X | EXXXXC | t=9
# X<| E | DXXXCX | t=10
# X<| X | DEXXCX | t=10
# X<| X | DXEXCX | t=10
# X<| X | DXXECX | t=10
# X<| X | DXXXCE | t=10
# X<| E | DXXCXX | t=10
# X<| X | DEXCXX | t=10
# X<| X | DXECXX | t=10
# X<| X | DXXCEX | t=10
# X<| X | DXXCXE | t=10
# C<| E | DXXXXX | t=10
# C<| X | DEXXXX | t=10
# C<| X | DXEXXX | t=10
# C<| X | DXXEXX | t=10
# C<| X | DXXXEX | t=10
# C<| X | DXXXXE | t=10
# X<| E | DXCXXX | t=10
# X<| X | DECXXX | t=10
# X<| X | DXCEXX | t=10
# X<| X | DXCXEX | t=10
# X<| X | DXCXXE | t=10
# X<| E | DCXXXX | t=10
# X<| X | DCEXXX | t=10
# X<| X | DCXEXX | t=10
# X<| X | DCXXEX | t=10
# X<| X | DCXXXE | t=10
# C |>X | DXEXXX | t=11
# C |>X | DXXEXX | t=11
# X |>E | DCXXXX | t=11
# X |>X | DXCXEX | t=11
# X |>X | DXXCEX | t=11
# X |>X | DECXXX | t=11
# X |>E | DXCXXX | t=11
# C |>X | DXXXEX | t=11
# X |>X | DXCEXX | t=11
# C |>X | DEXXXX | t=11
# X |>X | DEXCXX | t=11
# X |>X | DCXEXX | t=11
# C |>E | DXXXXX | t=11
# X |>E | DXXCXX | t=11
# X |>X | DCXXEX | t=11
# X |>X | DCEXXX | t=11
# X |>X | DXECXX | t=11
# X<| D | CXXEXX | t=12
# X<| X | CDXEXX | t=12
# X<| X | CXDEXX | t=12
# X<| X | CXXEDX | t=12
# X<| X | CXXEXD | t=12
# X<| D | CXEXXX | t=12
# X<| X | CDEXXX | t=12
# X<| X | CXEDXX | t=12
# X<| X | CXEXDX | t=12
# X<| X | CXEXXD | t=12
# X<| D | CEXXXX | t=12
# X<| X | CEDXXX | t=12
# X<| X | CEXDXX | t=12
# X<| X | CEXXDX | t=12
# X<| X | CEXXXD | t=12
# X<| ED | CXXXXX | t=12
# X<| D | CXXXEX | t=12
# X<| D | CXXXXE | t=12
# X<| E | CDXXXX | t=12
# X<| E | CXDXXX | t=12
# X<| E | CXXDXX | t=12
# X<| E | CXXXDX | t=12
# X<| E | CXXXXD | t=12
#
# Edges :
# X<| X | CXEXDX | t=0
# X |>X | CEXDXX | t=1
# ---
# X<| X | CXEXXD | t=0
# X |>X | CEXXDX | t=1
# ---
# X<| X | CXXXDE | t=0
# X |>X | CXXDEX | t=1
# ---
# X<| E | CXDXXX | t=0
# X |>E | CDXXXX | t=1
# ---
# X<| E | CXXDXX | t=0
# X |>E | CXDXXX | t=1
# ---
# E<| X | CXXXDX | t=0
# E |>X | CXXDXX | t=1
# ---
# D<| E | CXXXXX | t=0
# D |>E | CXXXXX | t=1
# ---
# X<| D | CXXEXX | t=0
# X |>D | CXEXXX | t=1
# ---
# X<| X | CXXDEX | t=0
# X |>X | CXDEXX | t=1
# ---
# X<| X | CXXEXD | t=0
# X |>X | CXEXDX | t=1
# ---
# D<| X | CXEXXX | t=0
# D |>X | CEXXXX | t=1
# ---
# X<| X | CXXXED | t=0
# X |>X | CXXEDX | t=1
# ---
# X<| X | CXXDXE | t=0
# X |>X | CXDXEX | t=1
# ---
# E<| X | CXXXXD | t=0
# E |>X | CXXXDX | t=1
# ---
# X<| DE | CXXXXX | t=0
# X |>DE | CXXXXX | t=1
# ---
# X<| D | CXXXEX | t=0
# X |>D | CXXEXX | t=1
# ---
# X<| D | CXXXXE | t=0
# X |>D | CXXXEX | t=1
# ---
# D<| X | CXXXEX | t=0
# D |>X | CXXEXX | t=1
# ---
# D<| X | CXXXXE | t=0
# D |>X | CXXXEX | t=1
# ---
# E<| X | CXXDXX | t=0
# E |>X | CXDXXX | t=1
# ---
# X<| X | CXDXXE | t=0
# X |>X | CDXXEX | t=1
# ---
# X<| E | CXXXXD | t=0
# X |>E | CXXXDX | t=1
# ---
# E<| D | CXXXXX | t=0
# E |>D | CXXXXX | t=1
# ---
# X<| X | CXXEDX | t=0
# X |>X | CXEDXX | t=1
# ---
# X<| X | CXDEXX | t=0
# X |>X | CDEXXX | t=1
# ---
# D<| X | CXXEXX | t=0
# D |>X | CXEXXX | t=1
# ---
# X<| X | CXEDXX | t=0
# X |>X | CEDXXX | t=1
# ---
# DE<| X | CXXXXX | t=0
# DE |>X | CXXXXX | t=1
# ---
# X<| D | CXEXXX | t=0
# X |>D | CEXXXX | t=1
# ---
# X<| X | CXDXEX | t=0
# X |>X | CDXEXX | t=1
# ---
# X<| E | CXXXDX | t=0
# X |>E | CXXDXX | t=1
# ---
# E<| X | CXDXXX | t=0
# E |>X | CDXXXX | t=1
# ---
# X |>X | CXXDEX | t=1
# X<| X | CXDEXX | t=2
# ---
# X |>E | CXDXXX | t=1
# X<| E | CDXXXX | t=2
# ---
# E |>X | CXXDXX | t=1
# E<| X | CXDXXX | t=2
# ---
# D |>E | CXXXXX | t=1
# D<| E | CXXXXX | t=2
# ---
# X |>D | CXEXXX | t=1
# X<| D | CEXXXX | t=2
# ---
# X |>X | CXDEXX | t=1
# X<| X | CDEXXX | t=2
# ---
# X |>X | CXEXDX | t=1
# X<| X | CEXDXX | t=2
# ---
# X |>X | CXXEDX | t=1
# X<| X | CXEDXX | t=2
# ---
# X |>X | CXDXEX | t=1
# X<| X | CDXEXX | t=2
# ---
# E |>X | CXXXDX | t=1
# E<| X | CXXDXX | t=2
# ---
# X |>DE | CXXXXX | t=1
# X<| DE | CXXXXX | t=2
# ---
# X |>D | CXXEXX | t=1
# X<| D | CXEXXX | t=2
# ---
# X |>D | CXXXEX | t=1
# X<| D | CXXEXX | t=2
# ---
# D |>X | CXXEXX | t=1
# D<| X | CXEXXX | t=2
# ---
# D |>X | CXXXEX | t=1
# D<| X | CXXEXX | t=2
# ---
# E |>X | CXDXXX | t=1
# E<| X | CDXXXX | t=2
# ---
# X |>E | CXXXDX | t=1
# X<| E | CXXDXX | t=2
# ---
# E |>D | CXXXXX | t=1
# E<| D | CXXXXX | t=2
# ---
# X |>X | CXEDXX | t=1
# X<| X | CEDXXX | t=2
# ---
# D |>X | CXEXXX | t=1
# D<| X | CEXXXX | t=2
# ---
# DE |>X | CXXXXX | t=1
# DE<| X | CXXXXX | t=2
# ---
# X |>E | CXXDXX | t=1
# X<| E | CXDXXX | t=2
# ---
# X<| X | CDXEXX | t=2
# C |>X | DXEXXX | t=3
# ---
# X<| X | CDXEXX | t=2
# X |>X | DCEXXX | t=3
# ---
# X<| X | CDXEXX | t=2
# X |>X | DXECXX | t=3
# ---
# X<| X | CDXEXX | t=2
# X |>X | DXEXCX | t=3
# ---
# X<| X | CDXEXX | t=2
# X |>X | DXEXXC | t=3
# ---
# D<| X | CXEXXX | t=2
# C |>X | DEXXXX | t=3
# ---
# X<| E | CDXXXX | t=2
# C |>E | DXXXXX | t=3
# ---
# X<| E | CDXXXX | t=2
# X |>E | DCXXXX | t=3
# ---
# X<| E | CDXXXX | t=2
# X |>E | DXCXXX | t=3
# ---
# X<| E | CDXXXX | t=2
# X |>E | DXXCXX | t=3
# ---
# X<| E | CDXXXX | t=2
# X |>E | DXXXCX | t=3
# ---
# X<| E | CDXXXX | t=2
# X |>E | DXXXXC | t=3
# ---
# E<| X | CDXXXX | t=2
# EC |>X | DXXXXX | t=3
# ---
# E<| X | CDXXXX | t=2
# C |>X | DEXXXX | t=3
# ---
# E<| X | CDXXXX | t=2
# C |>X | DXEXXX | t=3
# ---
# E<| X | CDXXXX | t=2
# C |>X | DXXEXX | t=3
# ---
# E<| X | CDXXXX | t=2
# C |>X | DXXXEX | t=3
# ---
# E<| X | CDXXXX | t=2
# C |>X | DXXXXE | t=3
# ---
# E<| X | CDXXXX | t=2
# E |>X | DCXXXX | t=3
# ---
# E<| X | CDXXXX | t=2
# E |>X | DXCXXX | t=3
# ---
# E<| X | CDXXXX | t=2
# E |>X | DXXCXX | t=3
# ---
# E<| X | CDXXXX | t=2
# E |>X | DXXXCX | t=3
# ---
# E<| X | CDXXXX | t=2
# E |>X | DXXXXC | t=3
# ---
# D<| E | CXXXXX | t=2
# C |>E | DXXXXX | t=3
# ---
# DE<| X | CXXXXX | t=2
# EC |>X | DXXXXX | t=3
# ---
# X<| X | CDEXXX | t=2
# C |>X | DEXXXX | t=3
# ---
# X<| X | CDEXXX | t=2
# X |>X | DECXXX | t=3
# ---
# X<| X | CDEXXX | t=2
# X |>X | DEXCXX | t=3
# ---
# X<| X | CDEXXX | t=2
# X |>X | DEXXCX | t=3
# ---
# X<| X | CDEXXX | t=2
# X |>X | DEXXXC | t=3
# ---
# D<| X | CXXEXX | t=2
# C |>X | DXEXXX | t=3
# ---
# C |>E | DXXXXX | t=3
# C<| D | EXXXXX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| D | EXXXXX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| X | EDXXXX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| X | EXDXXX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| X | EXXDXX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| X | EXXXDX | t=4
# ---
# C |>X | DEXXXX | t=3
# C<| X | EXXXXD | t=4
# ---
# X |>E | DXCXXX | t=3
# X<| D | ECXXXX | t=4
# ---
# X |>E | DXXCXX | t=3
# X<| D | EXCXXX | t=4
# ---
# X |>E | DXXXCX | t=3
# X<| D | EXXCXX | t=4
# ---
# X |>E | DXXXXC | t=3
# X<| D | EXXXCX | t=4
# ---
# X |>X | DECXXX | t=3
# X<| D | ECXXXX | t=4
# ---
# X |>X | DECXXX | t=3
# X<| X | ECDXXX | t=4
# ---
# X |>X | DECXXX | t=3
# X<| X | ECXDXX | t=4
# ---
# X |>X | DECXXX | t=3
# X<| X | ECXXDX | t=4
# ---
# X |>X | DECXXX | t=3
# X<| X | ECXXXD | t=4
# ---
# X |>X | DEXCXX | t=3
# X<| D | EXCXXX | t=4
# ---
# X |>X | DEXCXX | t=3
# X<| X | EDCXXX | t=4
# ---
# X |>X | DEXCXX | t=3
# X<| X | EXCDXX | t=4
# ---
# X |>X | DEXCXX | t=3
# X<| X | EXCXDX | t=4
# ---
# X |>X | DEXCXX | t=3
# X<| X | EXCXXD | t=4
# ---
# X |>X | DEXXCX | t=3
# X<| D | EXXCXX | t=4
# ---
# X |>X | DEXXCX | t=3
# X<| X | EDXCXX | t=4
# ---
# X |>X | DEXXCX | t=3
# X<| X | EXDCXX | t=4
# ---
# X |>X | DEXXCX | t=3
# X<| X | EXXCDX | t=4
# ---
# X |>X | DEXXCX | t=3
# X<| X | EXXCXD | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| D | EXXXCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| X | EDXXCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| X | EXDXCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| X | EXXDCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| X | EXXXCD | t=4
# ---
# X<| D | EXCXXX | t=4
# E |>D | XCXXXX | t=5
# ---
# X<| D | EXCXXX | t=4
# X |>D | XCEXXX | t=5
# ---
# X<| D | EXCXXX | t=4
# X |>D | XCXEXX | t=5
# ---
# X<| D | EXCXXX | t=4
# X |>D | XCXXEX | t=5
# ---
# X<| D | EXCXXX | t=4
# X |>D | XCXXXE | t=5
# ---
# X<| X | EXCDXX | t=4
# E |>X | XCDXXX | t=5
# ---
# X<| X | EXCDXX | t=4
# X |>X | XCDEXX | t=5
# ---
# X<| X | EXCDXX | t=4
# X |>X | XCDXEX | t=5
# ---
# X<| X | EXCDXX | t=4
# X |>X | XCDXXE | t=5
# ---
# X<| X | EXCXDX | t=4
# E |>X | XCXDXX | t=5
# ---
# X<| X | EXCXDX | t=4
# X |>X | XCEDXX | t=5
# ---
# X<| X | EXCXDX | t=4
# X |>X | XCXDEX | t=5
# ---
# X<| X | EXCXDX | t=4
# X |>X | XCXDXE | t=5
# ---
# X<| X | EXCXXD | t=4
# E |>X | XCXXDX | t=5
# ---
# X<| X | EXCXXD | t=4
# X |>X | XCEXDX | t=5
# ---
# X<| X | EXCXXD | t=4
# X |>X | XCXEDX | t=5
# ---
# X<| X | EXCXXD | t=4
# X |>X | XCXXDE | t=5
# ---
# C<| D | EXXXXX | t=4
# CE |>D | XXXXXX | t=5
# ---
# C<| D | EXXXXX | t=4
# E |>D | XCXXXX | t=5
# ---
# C<| D | EXXXXX | t=4
# E |>D | XXCXXX | t=5
# ---
# C<| D | EXXXXX | t=4
# E |>D | XXXCXX | t=5
# ---
# C<| D | EXXXXX | t=4
# E |>D | XXXXCX | t=5
# ---
# C<| D | EXXXXX | t=4
# E |>D | XXXXXC | t=5
# ---
# C<| D | EXXXXX | t=4
# C |>D | XEXXXX | t=5
# ---
# C<| D | EXXXXX | t=4
# C |>D | XXEXXX | t=5
# ---
# C<| D | EXXXXX | t=4
# C |>D | XXXEXX | t=5
# ---
# C<| D | EXXXXX | t=4
# C |>D | XXXXEX | t=5
# ---
# C<| D | EXXXXX | t=4
# C |>D | XXXXXE | t=5
# ---
# C<| X | EXDXXX | t=4
# CE |>X | XDXXXX | t=5
# ---
# C<| X | EXDXXX | t=4
# E |>X | XDCXXX | t=5
# ---
# C<| X | EXDXXX | t=4
# E |>X | XDXCXX | t=5
# ---
# C<| X | EXDXXX | t=4
# E |>X | XDXXCX | t=5
# ---
# C<| X | EXDXXX | t=4
# E |>X | XDXXXC | t=5
# ---
# C<| X | EXDXXX | t=4
# C |>X | XDEXXX | t=5
# ---
# C<| X | EXDXXX | t=4
# C |>X | XDXEXX | t=5
# ---
# C<| X | EXDXXX | t=4
# C |>X | XDXXEX | t=5
# ---
# C<| X | EXDXXX | t=4
# C |>X | XDXXXE | t=5
# ---
# C<| X | EXXDXX | t=4
# CE |>X | XXDXXX | t=5
# ---
# C<| X | EXXDXX | t=4
# E |>X | XCDXXX | t=5
# ---
# C<| X | EXXDXX | t=4
# E |>X | XXDCXX | t=5
# ---
# C<| X | EXXDXX | t=4
# E |>X | XXDXCX | t=5
# ---
# C<| X | EXXDXX | t=4
# E |>X | XXDXXC | t=5
# ---
# C<| X | EXXDXX | t=4
# C |>X | XEDXXX | t=5
# ---
# C<| X | EXXDXX | t=4
# C |>X | XXDEXX | t=5
# ---
# C<| X | EXXDXX | t=4
# C |>X | XXDXEX | t=5
# ---
# C<| X | EXXDXX | t=4
# C |>X | XXDXXE | t=5
# ---
# C<| X | EXXXDX | t=4
# CE |>X | XXXDXX | t=5
# ---
# C<| X | EXXXDX | t=4
# E |>X | XCXDXX | t=5
# ---
# C<| X | EXXXDX | t=4
# E |>X | XXCDXX | t=5
# ---
# C<| X | EXXXDX | t=4
# E |>X | XXXDCX | t=5
# ---
# C<| X | EXXXDX | t=4
# E |>X | XXXDXC | t=5
# ---
# C<| X | EXXXDX | t=4
# C |>X | XEXDXX | t=5
# ---
# C<| X | EXXXDX | t=4
# C |>X | XXEDXX | t=5
# ---
# C<| X | EXXXDX | t=4
# C |>X | XXXDEX | t=5
# ---
# C<| X | EXXXDX | t=4
# C |>X | XXXDXE | t=5
# ---
# C<| X | EXXXXD | t=4
# CE |>X | XXXXDX | t=5
# ---
# C<| X | EXXXXD | t=4
# E |>X | XCXXDX | t=5
# ---
# C<| X | EXXXXD | t=4
# E |>X | XXCXDX | t=5
# ---
# C<| X | EXXXXD | t=4
# E |>X | XXXCDX | t=5
# ---
# C<| X | EXXXXD | t=4
# E |>X | XXXXDC | t=5
# ---
# C<| X | EXXXXD | t=4
# C |>X | XEXXDX | t=5
# ---
# C<| X | EXXXXD | t=4
# C |>X | XXEXDX | t=5
# ---
# C<| X | EXXXXD | t=4
# C |>X | XXXEDX | t=5
# ---
# C<| X | EXXXXD | t=4
# C |>X | XXXXDE | t=5
# ---
# X<| D | EXXCXX | t=4
# E |>D | XXCXXX | t=5
# ---
# X<| D | EXXCXX | t=4
# X |>D | XECXXX | t=5
# ---
# X<| D | EXXCXX | t=4
# X |>D | XXCEXX | t=5
# ---
# X<| D | EXXCXX | t=4
# X |>D | XXCXEX | t=5
# ---
# X<| D | EXXCXX | t=4
# X |>D | XXCXXE | t=5
# ---
# X<| D | EXXXCX | t=4
# E |>D | XXXCXX | t=5
# ---
# X<| D | EXXXCX | t=4
# X |>D | XEXCXX | t=5
# ---
# X<| D | EXXXCX | t=4
# X |>D | XXECXX | t=5
# ---
# X<| D | EXXXCX | t=4
# X |>D | XXXCEX | t=5
# ---
# X<| D | EXXXCX | t=4
# X |>D | XXXCXE | t=5
# ---
# X<| X | EXDXCX | t=4
# E |>X | XDXCXX | t=5
# ---
# X<| X | EXDXCX | t=4
# X |>X | XDECXX | t=5
# ---
# X<| X | EXDXCX | t=4
# X |>X | XDXCEX | t=5
# ---
# X<| X | EXDXCX | t=4
# X |>X | XDXCXE | t=5
# ---
# X<| X | EXXDCX | t=4
# E |>X | XXDCXX | t=5
# ---
# X<| X | EXXDCX | t=4
# X |>X | XEDCXX | t=5
# ---
# X<| X | EXXDCX | t=4
# X |>X | XXDCEX | t=5
# ---
# X<| X | EXXDCX | t=4
# X |>X | XXDCXE | t=5
# ---
# X<| X | EXXXCD | t=4
# E |>X | XXXCDX | t=5
# ---
# X<| X | EXXXCD | t=4
# X |>X | XEXCDX | t=5
# ---
# X<| X | EXXXCD | t=4
# X |>X | XXECDX | t=5
# ---
# X<| X | EXXXCD | t=4
# X |>X | XXXCDE | t=5
# ---
# X<| X | EXDCXX | t=4
# E |>X | XDCXXX | t=5
# ---
# X<| X | EXDCXX | t=4
# X |>X | XDCEXX | t=5
# ---
# X<| X | EXDCXX | t=4
# X |>X | XDCXEX | t=5
# ---
# X<| X | EXDCXX | t=4
# X |>X | XDCXXE | t=5
# ---
# X<| X | EXXCDX | t=4
# E |>X | XXCDXX | t=5
# ---
# X<| X | EXXCDX | t=4
# X |>X | XECDXX | t=5
# ---
# X<| X | EXXCDX | t=4
# X |>X | XXCDEX | t=5
# ---
# X<| X | EXXCDX | t=4
# X |>X | XXCDXE | t=5
# ---
# X<| X | EXXCXD | t=4
# E |>X | XXCXDX | t=5
# ---
# X<| X | EXXCXD | t=4
# X |>X | XECXDX | t=5
# ---
# X<| X | EXXCXD | t=4
# X |>X | XXCEDX | t=5
# ---
# X<| X | EXXCXD | t=4
# X |>X | XXCXDE | t=5
# ---
# E |>D | XXCXXX | t=5
# E<| X | DCXXXX | t=6
# ---
# X |>D | XXCEXX | t=5
# X<| X | DCEXXX | t=6
# ---
# X |>D | XXCXEX | t=5
# X<| X | DCXEXX | t=6
# ---
# X |>D | XXCXXE | t=5
# X<| X | DCXXEX | t=6
# ---
# CE |>X | XDXXXX | t=5
# CE<| X | DXXXXX | t=6
# ---
# E |>X | XDCXXX | t=5
# E<| X | DCXXXX | t=6
# ---
# E |>X | XDXCXX | t=5
# E<| X | DXCXXX | t=6
# ---
# E |>X | XDXXCX | t=5
# E<| X | DXXCXX | t=6
# ---
# E |>X | XDXXXC | t=5
# E<| X | DXXXCX | t=6
# ---
# C |>X | XDEXXX | t=5
# C<| X | DEXXXX | t=6
# ---
# C |>X | XDXEXX | t=5
# C<| X | DXEXXX | t=6
# ---
# C |>X | XDXXEX | t=5
# C<| X | DXXEXX | t=6
# ---
# C |>X | XDXXXE | t=5
# C<| X | DXXXEX | t=6
# ---
# E |>D | XXXCXX | t=5
# E<| X | DXCXXX | t=6
# ---
# X |>D | XXECXX | t=5
# X<| X | DECXXX | t=6
# ---
# X |>D | XXXCEX | t=5
# X<| X | DXCEXX | t=6
# ---
# X |>D | XXXCXE | t=5
# X<| X | DXCXEX | t=6
# ---
# X |>X | XDECXX | t=5
# X<| X | DECXXX | t=6
# ---
# X |>X | XDXCEX | t=5
# X<| X | DXCEXX | t=6
# ---
# X |>X | XDXCXE | t=5
# X<| X | DXCXEX | t=6
# ---
# X |>X | XDCEXX | t=5
# X<| X | DCEXXX | t=6
# ---
# X |>X | XDCXEX | t=5
# X<| X | DCXEXX | t=6
# ---
# X |>X | XDCXXE | t=5
# X<| X | DCXXEX | t=6
# ---
# CE |>D | XXXXXX | t=5
# CE<| X | DXXXXX | t=6
# ---
# E |>D | XXXXCX | t=5
# E<| X | DXXCXX | t=6
# ---
# E |>D | XXXXXC | t=5
# E<| X | DXXXCX | t=6
# ---
# C |>D | XXEXXX | t=5
# C<| X | DEXXXX | t=6
# ---
# C |>D | XXXEXX | t=5
# C<| X | DXEXXX | t=6
# ---
# C |>D | XXXXEX | t=5
# C<| X | DXXEXX | t=6
# ---
# C |>D | XXXXXE | t=5
# C<| X | DXXXEX | t=6
# ---
# C<| X | DXEXXX | t=6
# CD |>X | XEXXXX | t=7
# ---
# C<| X | DXEXXX | t=6
# D |>X | XECXXX | t=7
# ---
# C<| X | DXEXXX | t=6
# D |>X | XEXCXX | t=7
# ---
# C<| X | DXEXXX | t=6
# D |>X | XEXXCX | t=7
# ---
# C<| X | DXEXXX | t=6
# D |>X | XEXXXC | t=7
# ---
# C<| X | DXEXXX | t=6
# C |>X | XEDXXX | t=7
# ---
# C<| X | DXEXXX | t=6
# C |>X | XEXDXX | t=7
# ---
# C<| X | DXEXXX | t=6
# C |>X | XEXXDX | t=7
# ---
# C<| X | DXEXXX | t=6
# C |>X | XEXXXD | t=7
# ---
# C<| X | DXXEXX | t=6
# CD |>X | XXEXXX | t=7
# ---
# C<| X | DXXEXX | t=6
# D |>X | XCEXXX | t=7
# ---
# C<| X | DXXEXX | t=6
# D |>X | XXECXX | t=7
# ---
# C<| X | DXXEXX | t=6
# D |>X | XXEXCX | t=7
# ---
# C<| X | DXXEXX | t=6
# D |>X | XXEXXC | t=7
# ---
# C<| X | DXXEXX | t=6
# C |>X | XDEXXX | t=7
# ---
# C<| X | DXXEXX | t=6
# C |>X | XXEDXX | t=7
# ---
# C<| X | DXXEXX | t=6
# C |>X | XXEXDX | t=7
# ---
# C<| X | DXXEXX | t=6
# C |>X | XXEXXD | t=7
# ---
# X<| X | DXCXEX | t=6
# D |>X | XCXEXX | t=7
# ---
# X<| X | DXCXEX | t=6
# X |>X | XCDEXX | t=7
# ---
# X<| X | DXCXEX | t=6
# X |>X | XCXEDX | t=7
# ---
# X<| X | DXCXEX | t=6
# X |>X | XCXEXD | t=7
# ---
# E<| X | DXXXCX | t=6
# ED |>X | XXXCXX | t=7
# ---
# E<| X | DXXXCX | t=6
# D |>X | XEXCXX | t=7
# ---
# E<| X | DXXXCX | t=6
# D |>X | XXECXX | t=7
# ---
# E<| X | DXXXCX | t=6
# D |>X | XXXCEX | t=7
# ---
# E<| X | DXXXCX | t=6
# D |>X | XXXCXE | t=7
# ---
# E<| X | DXXXCX | t=6
# E |>X | XDXCXX | t=7
# ---
# E<| X | DXXXCX | t=6
# E |>X | XXDCXX | t=7
# ---
# E<| X | DXXXCX | t=6
# E |>X | XXXCDX | t=7
# ---
# E<| X | DXXXCX | t=6
# E |>X | XXXCXD | t=7
# ---
# X<| X | DXCEXX | t=6
# D |>X | XCEXXX | t=7
# ---
# X<| X | DXCEXX | t=6
# X |>X | XCEDXX | t=7
# ---
# X<| X | DXCEXX | t=6
# X |>X | XCEXDX | t=7
# ---
# X<| X | DXCEXX | t=6
# X |>X | XCEXXD | t=7
# ---
# CE<| X | DXXXXX | t=6
# CED |>X | XXXXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# ED |>X | XCXXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# ED |>X | XXCXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# ED |>X | XXXCXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# ED |>X | XXXXCX | t=7
# ---
# CE<| X | DXXXXX | t=6
# ED |>X | XXXXXC | t=7
# ---
# CE<| X | DXXXXX | t=6
# CD |>X | XEXXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CD |>X | XXEXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CD |>X | XXXEXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CD |>X | XXXXEX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CD |>X | XXXXXE | t=7
# ---
# CE<| X | DXXXXX | t=6
# CE |>X | XDXXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CE |>X | XXDXXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CE |>X | XXXDXX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CE |>X | XXXXDX | t=7
# ---
# CE<| X | DXXXXX | t=6
# CE |>X | XXXXXD | t=7
# ---
# E<| X | DXXCXX | t=6
# ED |>X | XXCXXX | t=7
# ---
# E<| X | DXXCXX | t=6
# D |>X | XECXXX | t=7
# ---
# E<| X | DXXCXX | t=6
# D |>X | XXCEXX | t=7
# ---
# E<| X | DXXCXX | t=6
# D |>X | XXCXEX | t=7
# ---
# E<| X | DXXCXX | t=6
# D |>X | XXCXXE | t=7
# ---
# E<| X | DXXCXX | t=6
# E |>X | XDCXXX | t=7
# ---
# E<| X | DXXCXX | t=6
# E |>X | XXCDXX | t=7
# ---
# E<| X | DXXCXX | t=6
# E |>X | XXCXDX | t=7
# ---
# E<| X | DXXCXX | t=6
# E |>X | XXCXXD | t=7
# ---
# C<| X | DXXXEX | t=6
# CD |>X | XXXEXX | t=7
# ---
# C<| X | DXXXEX | t=6
# D |>X | XCXEXX | t=7
# ---
# C<| X | DXXXEX | t=6
# D |>X | XXCEXX | t=7
# ---
# C<| X | DXXXEX | t=6
# D |>X | XXXECX | t=7
# ---
# C<| X | DXXXEX | t=6
# D |>X | XXXEXC | t=7
# ---
# C<| X | DXXXEX | t=6
# C |>X | XDXEXX | t=7
# ---
# C<| X | DXXXEX | t=6
# C |>X | XXDEXX | t=7
# ---
# C<| X | DXXXEX | t=6
# C |>X | XXXEDX | t=7
# ---
# C<| X | DXXXEX | t=6
# C |>X | XXXEXD | t=7
# ---
# E<| X | DXCXXX | t=6
# ED |>X | XCXXXX | t=7
# ---
# E<| X | DXCXXX | t=6
# D |>X | XCEXXX | t=7
# ---
# E<| X | DXCXXX | t=6
# D |>X | XCXEXX | t=7
# ---
# E<| X | DXCXXX | t=6
# D |>X | XCXXEX | t=7
# ---
# E<| X | DXCXXX | t=6
# D |>X | XCXXXE | t=7
# ---
# E<| X | DXCXXX | t=6
# E |>X | XCDXXX | t=7
# ---
# E<| X | DXCXXX | t=6
# E |>X | XCXDXX | t=7
# ---
# E<| X | DXCXXX | t=6
# E |>X | XCXXDX | t=7
# ---
# E<| X | DXCXXX | t=6
# E |>X | XCXXXD | t=7
# ---
# D |>X | XCXEXX | t=7
# D<| X | CXEXXX | t=8
# ---
# X |>X | XCDEXX | t=7
# X<| X | CDEXXX | t=8
# ---
# X |>X | XCXEDX | t=7
# X<| X | CXEDXX | t=8
# ---
# X |>X | XCXEXD | t=7
# X<| X | CXEXDX | t=8
# ---
# ED |>X | XCXXXX | t=7
# ED<| X | CXXXXX | t=8
# ---
# D |>X | XCEXXX | t=7
# D<| X | CEXXXX | t=8
# ---
# D |>X | XCXXEX | t=7
# D<| X | CXXEXX | t=8
# ---
# D |>X | XCXXXE | t=7
# D<| X | CXXXEX | t=8
# ---
# E |>X | XCDXXX | t=7
# E<| X | CDXXXX | t=8
# ---
# E |>X | XCXDXX | t=7
# E<| X | CXDXXX | t=8
# ---
# E |>X | XCXXDX | t=7
# E<| X | CXXDXX | t=8
# ---
# E |>X | XCXXXD | t=7
# E<| X | CXXXDX | t=8
# ---
# X |>X | XCEDXX | t=7
# X<| X | CEDXXX | t=8
# ---
# X |>X | XCEXDX | t=7
# X<| X | CEXDXX | t=8
# ---
# X |>X | XCEXXD | t=7
# X<| X | CEXXDX | t=8
# ---
# X<| X | CEDXXX | t=8
# C |>X | EDXXXX | t=9
# ---
# X<| X | CEDXXX | t=8
# X |>X | EDCXXX | t=9
# ---
# X<| X | CEDXXX | t=8
# X |>X | EDXCXX | t=9
# ---
# X<| X | CEDXXX | t=8
# X |>X | EDXXCX | t=9
# ---
# X<| X | CEDXXX | t=8
# X |>X | EDXXXC | t=9
# ---
# ED<| X | CXXXXX | t=8
# DC |>X | EXXXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# DC |>X | EXXXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# C |>X | EDXXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# C |>X | EXDXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# C |>X | EXXDXX | t=9
# ---
# D<| X | CEXXXX | t=8
# C |>X | EXXXDX | t=9
# ---
# D<| X | CEXXXX | t=8
# C |>X | EXXXXD | t=9
# ---
# D<| X | CEXXXX | t=8
# D |>X | ECXXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# D |>X | EXCXXX | t=9
# ---
# D<| X | CEXXXX | t=8
# D |>X | EXXCXX | t=9
# ---
# D<| X | CEXXXX | t=8
# D |>X | EXXXCX | t=9
# ---
# D<| X | CEXXXX | t=8
# D |>X | EXXXXC | t=9
# ---
# E<| X | CXXDXX | t=8
# C |>X | EXDXXX | t=9
# ---
# X<| X | CEXDXX | t=8
# C |>X | EXDXXX | t=9
# ---
# X<| X | CEXDXX | t=8
# X |>X | ECDXXX | t=9
# ---
# X<| X | CEXDXX | t=8
# X |>X | EXDCXX | t=9
# ---
# X<| X | CEXDXX | t=8
# X |>X | EXDXCX | t=9
# ---
# X<| X | CEXDXX | t=8
# X |>X | EXDXXC | t=9
# ---
# X<| X | CEXXDX | t=8
# C |>X | EXXDXX | t=9
# ---
# X<| X | CEXXDX | t=8
# X |>X | ECXDXX | t=9
# ---
# X<| X | CEXXDX | t=8
# X |>X | EXCDXX | t=9
# ---
# X<| X | CEXXDX | t=8
# X |>X | EXXDCX | t=9
# ---
# X<| X | CEXXDX | t=8
# X |>X | EXXDXC | t=9
# ---
# E<| X | CXXXDX | t=8
# C |>X | EXXDXX | t=9
# ---
# E<| X | CXDXXX | t=8
# C |>X | EDXXXX | t=9
# ---
# C |>X | EDXXXX | t=9
# C<| E | DXXXXX | t=10
# ---
# C |>X | EDXXXX | t=9
# C<| X | DEXXXX | t=10
# ---
# C |>X | EDXXXX | t=9
# C<| X | DXEXXX | t=10
# ---
# C |>X | EDXXXX | t=9
# C<| X | DXXEXX | t=10
# ---
# C |>X | EDXXXX | t=9
# C<| X | DXXXEX | t=10
# ---
# C |>X | EDXXXX | t=9
# C<| X | DXXXXE | t=10
# ---
# X |>X | EDCXXX | t=9
# X<| E | DCXXXX | t=10
# ---
# X |>X | EDCXXX | t=9
# X<| X | DCEXXX | t=10
# ---
# X |>X | EDCXXX | t=9
# X<| X | DCXEXX | t=10
# ---
# X |>X | EDCXXX | t=9
# X<| X | DCXXEX | t=10
# ---
# X |>X | EDCXXX | t=9
# X<| X | DCXXXE | t=10
# ---
# X |>X | EDXCXX | t=9
# X<| E | DXCXXX | t=10
# ---
# X |>X | EDXCXX | t=9
# X<| X | DECXXX | t=10
# ---
# X |>X | EDXCXX | t=9
# X<| X | DXCEXX | t=10
# ---
# X |>X | EDXCXX | t=9
# X<| X | DXCXEX | t=10
# ---
# X |>X | EDXCXX | t=9
# X<| X | DXCXXE | t=10
# ---
# X |>X | EDXXCX | t=9
# X<| E | DXXCXX | t=10
# ---
# X |>X | EDXXCX | t=9
# X<| X | DEXCXX | t=10
# ---
# X |>X | EDXXCX | t=9
# X<| X | DXECXX | t=10
# ---
# X |>X | EDXXCX | t=9
# X<| X | DXXCEX | t=10
# ---
# X |>X | EDXXCX | t=9
# X<| X | DXXCXE | t=10
# ---
# X |>X | EDXXXC | t=9
# X<| E | DXXXCX | t=10
# ---
# X |>X | EDXXXC | t=9
# X<| X | DEXXCX | t=10
# ---
# X |>X | EDXXXC | t=9
# X<| X | DXEXCX | t=10
# ---
# X |>X | EDXXXC | t=9
# X<| X | DXXECX | t=10
# ---
# X |>X | EDXXXC | t=9
# X<| X | DXXXCE | t=10
# ---
# X<| E | DXXXCX | t=10
# X |>E | DXXCXX | t=11
# ---
# X<| X | DXEXCX | t=10
# X |>X | DEXCXX | t=11
# ---
# X<| X | DXXECX | t=10
# X |>X | DXECXX | t=11
# ---
# X<| X | DXXXCE | t=10
# X |>X | DXXCEX | t=11
# ---
# X<| E | DXXCXX | t=10
# X |>E | DXCXXX | t=11
# ---
# X<| X | DXECXX | t=10
# X |>X | DECXXX | t=11
# ---
# X<| X | DXXCEX | t=10
# X |>X | DXCEXX | t=11
# ---
# X<| X | DXXCXE | t=10
# X |>X | DXCXEX | t=11
# ---
# C<| E | DXXXXX | t=10
# C |>E | DXXXXX | t=11
# ---
# C<| X | DXEXXX | t=10
# C |>X | DEXXXX | t=11
# ---
# C<| X | DXXEXX | t=10
# C |>X | DXEXXX | t=11
# ---
# C<| X | DXXXEX | t=10
# C |>X | DXXEXX | t=11
# ---
# C<| X | DXXXXE | t=10
# C |>X | DXXXEX | t=11
# ---
# X<| E | DXCXXX | t=10
# X |>E | DCXXXX | t=11
# ---
# X<| X | DXCEXX | t=10
# X |>X | DCEXXX | t=11
# ---
# X<| X | DXCXEX | t=10
# X |>X | DCXEXX | t=11
# ---
# X<| X | DXCXXE | t=10
# X |>X | DCXXEX | t=11
# ---
# X |>E | DCXXXX | t=11
# X<| ED | CXXXXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| D | CEXXXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| D | CXEXXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| D | CXXEXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| D | CXXXEX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| D | CXXXXE | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| E | CDXXXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| E | CXDXXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| E | CXXDXX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| E | CXXXDX | t=12
# ---
# X |>E | DCXXXX | t=11
# X<| E | CXXXXD | t=12
# ---
# X |>X | DCXEXX | t=11
# X<| D | CXEXXX | t=12
# ---
# X |>X | DCXEXX | t=11
# X<| X | CDEXXX | t=12
# ---
# X |>X | DCXEXX | t=11
# X<| X | CXEDXX | t=12
# ---
# X |>X | DCXEXX | t=11
# X<| X | CXEXDX | t=12
# ---
# X |>X | DCXEXX | t=11
# X<| X | CXEXXD | t=12
# ---
# X |>X | DCXXEX | t=11
# X<| D | CXXEXX | t=12
# ---
# X |>X | DCXXEX | t=11
# X<| X | CDXEXX | t=12
# ---
# X |>X | DCXXEX | t=11
# X<| X | CXDEXX | t=12
# ---
# X |>X | DCXXEX | t=11
# X<| X | CXXEDX | t=12
# ---
# X |>X | DCXXEX | t=11
# X<| X | CXXEXD | t=12
# ---
# X |>X | DCEXXX | t=11
# X<| D | CEXXXX | t=12
# ---
# X |>X | DCEXXX | t=11
# X<| X | CEDXXX | t=12
# ---
# X |>X | DCEXXX | t=11
# X<| X | CEXDXX | t=12
# ---
# X |>X | DCEXXX | t=11
# X<| X | CEXXDX | t=12
# ---
# X |>X | DCEXXX | t=11
# X<| X | CEXXXD | t=12
# ---

# %%
#test.draw(notebook=False)

# %%
for node in test.final_states:
    print(node)
# Out:
# X<| ED | CXXXXX | t=12

# %%
test.elagate()

# %%
print("Nodes :")
for node in aut.nodes:
    print(node)
print("\nEdges :")
for edge in aut.edges:
    print(edge[0])
    print(edge[1])
    print("---")
# Out:
# Nodes :
# X<| E | CXXDXX | t=0
# X<| X | CXXDEX | t=0
# X |>E | CXDXXX | t=1
# X |>X | CXDEXX | t=1
# X<| E | CDXXXX | t=2
# X<| X | CDEXXX | t=2
# X |>E | DXXXXC | t=3
# X |>X | DEXXXC | t=3
# X<| D | EXXXCX | t=4
# X<| X | EXDXCX | t=4
# X |>D | XXXCEX | t=5
# X |>X | XDXCEX | t=5
# X<| X | DXCEXX | t=6
# X |>X | XCEDXX | t=7
# X<| X | CEDXXX | t=8
# X |>X | EDXCXX | t=9
# X<| E | DXCXXX | t=10
# X |>E | DCXXXX | t=11
# X<| ED | CXXXXX | t=12
#
# Edges :
# X<| E | CXXDXX | t=0
# X |>E | CXDXXX | t=1
# ---
# X<| X | CXXDEX | t=0
# X |>X | CXDEXX | t=1
# ---
# X |>E | CXDXXX | t=1
# X<| E | CDXXXX | t=2
# ---
# X |>X | CXDEXX | t=1
# X<| X | CDEXXX | t=2
# ---
# X<| E | CDXXXX | t=2
# X |>E | DXXXXC | t=3
# ---
# X<| X | CDEXXX | t=2
# X |>X | DEXXXC | t=3
# ---
# X |>E | DXXXXC | t=3
# X<| D | EXXXCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| D | EXXXCX | t=4
# ---
# X |>X | DEXXXC | t=3
# X<| X | EXDXCX | t=4
# ---
# X<| D | EXXXCX | t=4
# X |>D | XXXCEX | t=5
# ---
# X<| X | EXDXCX | t=4
# X |>X | XDXCEX | t=5
# ---
# X |>D | XXXCEX | t=5
# X<| X | DXCEXX | t=6
# ---
# X |>X | XDXCEX | t=5
# X<| X | DXCEXX | t=6
# ---
# X<| X | DXCEXX | t=6
# X |>X | XCEDXX | t=7
# ---
# X |>X | XCEDXX | t=7
# X<| X | CEDXXX | t=8
# ---
# X<| X | CEDXXX | t=8
# X |>X | EDXCXX | t=9
# ---
# X |>X | EDXCXX | t=9
# X<| E | DXCXXX | t=10
# ---
# X<| E | DXCXXX | t=10
# X |>E | DCXXXX | t=11
# ---
# X |>E | DCXXXX | t=11
# X<| ED | CXXXXX | t=12
# ---

# %%
test.draw(path="acdll3.svg", notebook=False)
